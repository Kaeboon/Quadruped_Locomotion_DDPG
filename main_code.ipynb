# %% [markdown]
# # Learning Agent Code (ME5418 Group 18)

# %% [markdown]
# Please edit the `TRAINING` and `Policy` Variable below, then run through every cell.

# %%
TRAINING = False # Set to True if you want to train from scratch. Set to False if you want to test our model.
Policy = 3 # Set which policy you want to test/evaluate. For training, set to 0.

# %% [markdown]
# ### Import libraries Cell

# %%
import gym
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import pickle
import imageio

# Import gym environment and DDPG (actor, critic, target) networks
from aliengo_gym import AliengoEnv
from DDPGNet import DDPGNet
from DDPGNet import scale_actions
from DDPGNet import scale_observation
from DDPGNet import OUNoise

# check your computer information
from tensorflow.python.client import device_lib
dev_list = device_lib.list_local_devices()
print(dev_list)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12698707614472741894
# ]

# %% [markdown]
# ### Parameter Cell: Initialize parameters and helper functions

# %% [markdown]
# Default parameters:

# %%
# Path to the folders saving the model parameters, render gifs, tf summary, and episode buffer informations
model_path = os.path.dirname(os.path.abspath('__file__')) +  "/model_save"
gifs_path = os.path.dirname(os.path.abspath('__file__')) + "/gifs_save"
train_path = os.path.dirname(os.path.abspath('__file__')) + "/tf_summary_save"
episode_buffer_path = os.path.dirname(os.path.abspath('__file__')) + "/episode_buffer_save"

# To load previously trained model?

if TRAINING == True:
    Policy = 0 # Set to 0 if you want to start from scratch. Else, set your policy value.

if Policy == 0:
    load_model = False # Toggle True to load previously trained model
elif Policy == 1:
    load_model = True
    MODEL_NUMBER = 2600 # which model number you want to load?
elif Policy == 2:
    load_model = True
    MODEL_NUMBER = 500 # which model number you want to load?
elif Policy == 3:
    load_model = True
    MODEL_NUMBER = 200 # which model number you want to load?
else:
    load_model = False
    MODEL_NUMBER = 0

# Parameters that decides when to save the model checkpoint, render gifs, tf summary and episode buffer informations.

# Save GIF
OUTPUT_GIFS = True # toggle True to save GIFS
NEXT_GIF_COUNT = 100 # To save GIFS at every NEXT_GIFS_COUNT episodes interval

# Save episode buffer, tf summary and model checkpoint
SAVE_EPISODE_BUFFER = True # toggle True to save episode buffer
SUMMARY_WINDOW = 5  # To save tf summary, and save model checkpoint at every SUMMARY_WINDOW episodes interval

# global variables used tensorboard visualization. tf summary will be saved to these two variable and regularly  written out to local files
episode_rewards = [] # do not edit
episode_lengths = [] # do not edit

# TRAINING and TESTING: 
MAX_EPISODE_LENGTH = 1000 # maximum steps to run in each episode during testing

episode_count = 0 # (do not edit this variable) gloal variable to save how much episodes has already been gone through

# TESTING
NUM_EXPS = 1 # How many episodes you want to test?

# TRAINING: for initializing actor, critic, target actor, target critic network
observe_size = 40
action_size = 8

# TRAINING: for initializing actor, critic, target actor, target critic's trainer

# TRAINING: for storing experience buffer and extracting a batch of experiences
EXPERIENCE_BUFFER_SIZE = 10 # How much experience should be stored in the experience buffer before being used for backward pass.
BATCH_SIZE = 10 # How much experiences should be extracted out from the experience buffer to be used for backward pass

# TRAINING: for OU Noise parameter
MU = 0.0
THETA = 0.15
SIGMA = 0.2
DECAY_R = 0.99
RESET_INTERVAL = 100

# - for updating actor network
ACTOR_LR = 1e-3
ACTOR_L2_REG = 1e-5
ACTOR_GRAD_CLIP = 1
# - for updating critic network
CRITIC_LR = 1e-3
CRITIC_L2_REG = 2e-4
CRITIC_GRAD_CLIP = 1
# - for soft updating target network
GAMMA = 0.99 
TAU = 1e-3

# Save render to gif helper function
def make_gif(images, fname):
    imageio.mimwrite(fname, images, subrectangles=True)
    print(f"Episode {episode_count - 1}. GIF is saved")

# %% [markdown]
# ### Worker Cell: To define Worker Agent

# %%
class Worker:
    
    def __init__(self, game, global_network, noise):
        self.env = game # Give it access to our GYM environment
        self.global_network = global_network # Give it access to our actor, critic, target actor, target critic network
        self.noise = noise # Give it access to our noise instance

    def train(self, rollout, sess):
        global episode_count
        
        # To randomly sample a few of experience from the replay buffer, then do some reshaping of their dimension to fit the dimension of our input layers.
        batch = np.array(random.sample(rollout, min(BATCH_SIZE, len(rollout))), dtype=object) 
        current_observations = np.stack(batch[:, 0])
        actions = np.stack(batch[:, 1])
        next_observations = np.stack(batch[:, 2])
        rewards = np.stack(batch[:, 3])

        # Backward pass for actor network, obtain actor loss
        feed_dict = {self.global_network.observation_input_placeholder: current_observations}

        actor_loss, _ = sess.run([self.global_network.actor_loss, self.global_network.actor_trainer], feed_dict = feed_dict)

        # Backward pass for critic network, obtain critic loss
        feed_dict = {self.global_network.observation_input_placeholder: current_observations,
                     self.global_network.action_input_placeholder: actions,
                     self.global_network.reward_placeholder: rewards,
                     self.global_network.next_observation_input_placeholder: next_observations}
        
        critic_loss, _ = sess.run([self.global_network.critic_loss, self.global_network.critic_trainer], feed_dict=feed_dict) 

        # Soft update for Target Actor and Target Critics
        _ = sess.run(self.global_network.update_target_ops)

        return actor_loss, critic_loss

    def shouldRun(self, coord, episode_count): # Just a method to decide when to stop the training / testing operation
        if TRAINING:
            return (not coord.should_stop()) # For training, this is just an infinity loop
        else:
            return (episode_count < NUM_EXPS) # For testing, it will only run for NUM_EXPS episodes.

    def work(self, sess, coord, saver, summary): 

        global episode_count, episode_rewards, episode_lengths # global variable for saving information that would be passed to global_summary at fixed interval
        # episode_count -> how many episode has been gone through
        # episode_rewards -> a list of (the sum of all reward obtain at each step at current episode)
        # episode_lengths -> a list of (how many steps are taken at current episode)

        self.global_summary = summary # our tf summary file writer -> for tensorboard visualization use

        self.nextGIF = episode_count # nextGIF will decide at which episode should the training render be saved as GIF

        with sess.as_default(), sess.graph.as_default(): # session (sess) and its associated graph become the default session and default graph.

            while self.shouldRun(coord, episode_count): # LOOP THRU EPISODES

                episode_buffer = [] # Clean out the episode buffer. Used to save our experiences
                episode_reward = 0 # Clean out the episode reward. Used to save all 
                
                d = False # Has it reached the termination state? Later on this value will be re-evaluated after each env.step()
                saveGIF = False # Do I need to save GIF for this episode? Later on this value will be re-evaluated according to the nextGIF value.

                self.env.reset(reload_urdf=False) # Reset environemnt -> return aliengo robot back to initial position orientation.
                self.noise.reset() # reset OU noise state
                
                if OUTPUT_GIFS:

                    if (not TRAINING) or (episode_count >= self.nextGIF): # To evaluate whether saving GIF is needed. Always True for testing. Only once a NEXT_GIF_COUNT for training
                        saveGIF = True
                        self.nextGIF = episode_count + NEXT_GIF_COUNT
                        GIF_episode = int(episode_count)
                        episode_frames = [self.env.render()] # save the render RGB array into our episode_frames
                
                episode_step_count = 0 # Number of steps taken in one episode

                while True: # LOOP THRU STEPS

                    # Please note that:
                    # s: current observation. a: action taken. s1: next observation. r: reward. d: is it termination state?

                    if episode_step_count == 0:
                        s = self.env.get_state() # Get current state
                        a = [0,0,0,0,0,0,0,0]

                    # Just reshaping the state data
                    s_list = []
                    s_list.append((scale_observation(s, a), )) # normalize state values
                    s_list = np.array(s_list, dtype=object)
                    s = np.stack(s_list[:, 0])

                    # Obtain the action as output by our actor network based on current state
                    feed_dict = {self.global_network.observation_input_placeholder: s}
                    a = sess.run(self.global_network.actor_net_output, feed_dict = feed_dict)

                    if TRAINING:
                        a = self.noise.get_action(action=a) # Add noise to our state using OU Noise
                    
                    a = (a + 1)*(26.5+26.5)/2 - 26.5 # undo the normalization
                    a = tuple(a[0]) # reshaping the action value
                    
                    # Perform a step to obtain next state, reward, is it termination state
                    s, _, s1, r, d, pa = self.env.step(a , episode_step_count)
                    
                    if saveGIF:
                        episode_frames.append(self.env.render()) # only add a new RGB array of current render if saving GIF is required

                    episode_buffer.append((scale_observation(s, scale_actions(pa)), scale_actions(a), scale_observation(s1, scale_actions(a)), np.array(r), np.array(d))) # then append the experience (s, a, s1, r, d) to our episode buffer
                    episode_reward += r # add value to our episode_reward
                    s = s1 # now next observation will be our current observation for the next loop
                    
                    episode_step_count +=1 # update episode step count

                    if TRAINING and (len(episode_buffer) % EXPERIENCE_BUFFER_SIZE == 0 or d): # once it episode buffer has stored as much as the EXPERIENCE BUFFER SIZE, backward pass will be performed.
                        if (len(episode_buffer) >= EXPERIENCE_BUFFER_SIZE):
                            episode_buffer_training = episode_buffer[-EXPERIENCE_BUFFER_SIZE:] # Only obtain the last EXPERIENCE_BUFFER_SIZE of experiences for backward pass
                        else:
                            episode_buffer_training = episode_buffer[:] # Get all of the experience buffer to be used for training
                        
                        actor_loss, critic_loss = self.train(episode_buffer_training, sess) # calling the train method

                        print(f"Episode {episode_count}. Training Carried out at step = {episode_step_count}. Actorloss = {actor_loss}, Critic_loss = {critic_loss}")

                    if episode_step_count >= MAX_EPISODE_LENGTH or d: # check if termination state is reached 
                        if d == True:
                            print(f"Episode: {episode_count}. Termination state hit at step = {episode_step_count}") 
                        break
                
                # Update our global variables used for tf.summary
                episode_lengths.append(episode_step_count)
                episode_rewards.append(episode_reward)

                episode_count += 1

                if not TRAINING: # Print our testing information
                    print(f"Episode {episode_count-1} Completed. Total step = {episode_step_count}. \n")
                    print("Saving GIF ......")
                    GIF_episode = int(episode_count)
                
                else: # if TRAINING

                    if episode_count % SUMMARY_WINDOW == 0: # check if needed to save tf summary for tensorboard visualization, and update our model checkpoint

                        # Save Model Checkpoint

                        saver.save(sess, model_path+'/model-'+str(int(episode_count))+'.ckpt')
                        print(f"Episode {episode_count-1}. Model checkpoint is saved \n")
                        
                        # To update our tf.summary and Tensorboard Visualization

                        summary = tf.Summary()

                        mean_reward = np.nanmean(episode_rewards[-SUMMARY_WINDOW:])
                        mean_length = np.nanmean(episode_lengths[-SUMMARY_WINDOW:]) 
                        summary.value.add(tag='Perf/Reward', simple_value = mean_reward)
                        summary.value.add(tag='Perf/Length', simple_value = mean_length) 
                        summary.value.add(tag="Losses/Actor Loss", simple_value = actor_loss )
                        summary.value.add(tag="Losses/Critic Loss", simple_value = critic_loss )# In truth, within one episode, there will be multiple backward pass. Here only takes in the last backward pass loss

                        self.global_summary.add_summary(summary, int(episode_count))
                        self.global_summary.flush()

                        print(f"Episode {episode_count-1}. tf.summary -> Tensorboard is updated \n")

                if saveGIF:

                    # To generate GIF file. file name format: episode_<which episodes>_<how many steps taken>_<how much is the reward in this episode>

                    images = np.array(episode_frames)
                    if TRAINING:
                        make_gif(images, "{}/episode_{:d}_{:d}_{:.1f}.gif".format(gifs_path, GIF_episode, episode_step_count, episode_reward))
                    else:
                        make_gif(images, '{}/episode_{:d}_{:d}.gif'.format(gifs_path, GIF_episode, episode_step_count))
                
                if SAVE_EPISODE_BUFFER:

                    # To save the experience buffer. file name format: episode_<which episode>

                    with open(episode_buffer_path + "/episode_{}.dat".format(GIF_episode), "wb") as file:
                        pickle.dump(episode_buffer, file)

        self.env.disconnect() # To terminate the PyBullet window after training is over. This would not run if training is stop manually, thus the extra last cell in this notebook.

# %% [markdown]
# ### Main code Cell: to start training / testing
# Training normally would run in infinity loop. To terminate, just stop the cell

# %%
tf.reset_default_graph()
print("Hello World!")
if not os.path.exists(model_path):
    os.makedirs(model_path)
if not os.path.exists(gifs_path):
    os.makedirs(gifs_path)
if not os.path.exists(train_path):
    os.makedirs(train_path)
if not os.path.exists(episode_buffer_path):
    os.makedirs(episode_buffer_path)

config = tf.ConfigProto(allow_soft_placement = True) #  to allow the placement of an operation on a device other than the one explicitly requested

with tf.device("/cpu:0"): # for now just use cpu to run. Might consider changing to gpu in the future to speed up training process.
     
    master_network = DDPGNet(observe_size=observe_size, action_size=action_size, TRAINING=TRAINING, gamma=GAMMA, tau=TAU, actor_lr=ACTOR_LR, actor_l2_reg=ACTOR_L2_REG, actor_grad_clip=ACTOR_GRAD_CLIP, critic_lr=CRITIC_LR, critic_l2_reg=CRITIC_L2_REG, critic_grad_clip=CRITIC_GRAD_CLIP, batch_size=BATCH_SIZE)

    gameEnv = AliengoEnv(render = True, Policy = Policy) # For us to visualize how each episode runs
    gameEnv.reset(reload_urdf=True) # To import the model in
    noise = OUNoise(MU, THETA, SIGMA, DECAY_R) # initializing OU Noise
    noise.reset() # reset the OU noise
    worker = Worker(gameEnv, master_network, noise) # Initialize our Worker Agent

    global_summary = tf.summary.FileWriter(train_path) # Initializing our tf summary -> for tensorboard visualisation
    saver = tf.train.Saver(max_to_keep = 2) # Initializing our tf saver -> for saving -> for saving model checkpoint

    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
        coord = tf.train.Coordinator()

        if load_model == True: # To load the model back from our tf checkpoint files
            print("Loading Model...")
            if not TRAINING:
                with open(model_path+'/checkpoint', 'w') as file:
                    file.write('model_checkpoint_path: "model-{}.ckpt"'.format(MODEL_NUMBER))
                    file.close()
            ckpt = tf.train.get_checkpoint_state(model_path)
            p=ckpt.model_checkpoint_path
            p=p[p.find('-')+1:]
            p=p[:p.find('.')]
            if TRAINING:
                episode_count = int(p)
            else:
                episode_count = 0
            saver.restore(sess,ckpt.model_checkpoint_path)
            print("episode_count set to ", episode_count)
         
        worker.work(sess, coord, saver, global_summary) # Start Training / Testing operation
            
# if not TRAINING:
#     print([np.mean(episode_lengths), np.sqrt(np.var(episode_lengths)), np.mean(np.asarray(np.asarray(episode_lengths) < MAX_EPISODE_LENGTH, dtype=float))])
# Out:
# Hello World!
# Episode 0. Training Carried out at step = 10. Actorloss = -0.10084936767816544, Critic_loss = 0.19393768906593323
# Episode 0. Training Carried out at step = 20. Actorloss = -0.10078724473714828, Critic_loss = 0.23839206993579865
# Episode 0. Training Carried out at step = 30. Actorloss = -0.10066451877355576, Critic_loss = 0.08062668144702911
# Episode 0. Training Carried out at step = 40. Actorloss = -0.10048141330480576, Critic_loss = 0.7169147729873657
# Episode 0. Training Carried out at step = 50. Actorloss = -0.10023824870586395, Critic_loss = 2.960627317428589
# Episode 0. Training Carried out at step = 60. Actorloss = -0.09993439167737961, Critic_loss = 3.127807855606079
# Episode 0. Training Carried out at step = 70. Actorloss = -0.09956994652748108, Critic_loss = 0.15807391703128815
# Episode 0. Training Carried out at step = 80. Actorloss = -0.09914487600326538, Critic_loss = 0.08000321686267853
# Episode 0. Training Carried out at step = 90. Actorloss = -0.09867988526821136, Critic_loss = 0.11572252959012985
# Episode 0. Training Carried out at step = 100. Actorloss = -0.09819163382053375, Critic_loss = 0.0844176635146141
# Episode 0. Training Carried out at step = 110. Actorloss = -0.09769285470247269, Critic_loss = 0.08184611052274704
# Episode 0. Training Carried out at step = 120. Actorloss = -0.09719406068325043, Critic_loss = 0.061736371368169785
# Episode 0. Training Carried out at step = 130. Actorloss = -0.09670402854681015, Critic_loss = 0.005886937957257032
# Episode 0. Training Carried out at step = 140. Actorloss = -0.09622959047555923, Critic_loss = 0.0033108582720160484
# Episode 0. Training Carried out at step = 150. Actorloss = -0.09576620906591415, Critic_loss = 0.01769605278968811
# Episode 0. Training Carried out at step = 160. Actorloss = -0.09530431032180786, Critic_loss = 0.025503812357783318
# Episode 0. Training Carried out at step = 170. Actorloss = -0.09483558684587479, Critic_loss = 0.0077078272588551044
# Episode 0. Training Carried out at step = 180. Actorloss = -0.0943535640835762, Critic_loss = 0.0021409266628324986
# Episode 0. Training Carried out at step = 190. Actorloss = -0.09385696053504944, Critic_loss = 0.0021699476055800915
# Episode 0. Training Carried out at step = 200. Actorloss = -0.09334976226091385, Critic_loss = 0.00455308984965086
# Episode 0. Training Carried out at step = 210. Actorloss = -0.09283870458602905, Critic_loss = 0.005308548919856548
# Episode 0. Training Carried out at step = 220. Actorloss = -0.09233085811138153, Critic_loss = 0.0035421140491962433
# Episode 0. Training Carried out at step = 230. Actorloss = -0.09183119982481003, Critic_loss = 0.001980007393285632
# Episode 0. Training Carried out at step = 240. Actorloss = -0.09133661538362503, Critic_loss = 0.004679025616496801
# Episode 0. Training Carried out at step = 250. Actorloss = -0.09084095805883408, Critic_loss = 0.00482729310169816
# Episode 1. Training Carried out at step = 150. Actorloss = -0.04914834350347519, Critic_loss = 0.0209856815636158
# Episode 1. Training Carried out at step = 160. Actorloss = -0.04896204546093941, Critic_loss = 0.01141146756708622
# Episode 1. Training Carried out at step = 170. Actorloss = -0.048808854073286057, Critic_loss = 0.006054960191249847
# Episode 1. Training Carried out at step = 180. Actorloss = -0.04869508743286133, Critic_loss = 0.0034716748632490635
# Episode 1. Training Carried out at step = 190. Actorloss = -0.04864306375384331, Critic_loss = 0.0015190653502941132
# Episode 1. Training Carried out at step = 200. Actorloss = -0.048621226102113724, Critic_loss = 0.09009160846471786
# Episode 1. Training Carried out at step = 210. Actorloss = -0.04862825945019722, Critic_loss = 0.23230278491973877
# Episode 1. Training Carried out at step = 220. Actorloss = -0.04865401238203049, Critic_loss = 0.34996524453163147
# Episode 1. Training Carried out at step = 230. Actorloss = -0.04869508370757103, Critic_loss = 0.431083619594574
# Episode 1. Training Carried out at step = 240. Actorloss = -0.048732396215200424, Critic_loss = 0.4280276596546173
# Episode 1. Training Carried out at step = 250. Actorloss = -0.04876699671149254, Critic_loss = 0.19571448862552643
# Episode 1. Training Carried out at step = 260. Actorloss = -0.04878031834959984, Critic_loss = 0.17717842757701874
# Episode 1. Training Carried out at step = 270. Actorloss = -0.048777833580970764, Critic_loss = 0.12885834276676178
# Episode 1. Training Carried out at step = 280. Actorloss = -0.04877222701907158, Critic_loss = 0.5837669372558594
# Episode 1. Training Carried out at step = 290. Actorloss = -0.04872209578752518, Critic_loss = 1.5102967023849487
# Episode 1. Training Carried out at step = 300. Actorloss = -0.04864000901579857, Critic_loss = 1.9767022132873535
# Episode 1. Training Carried out at step = 310. Actorloss = -0.04852619394659996, Critic_loss = 2.209768533706665
# Episode 1. Training Carried out at step = 320. Actorloss = -0.04837661609053612, Critic_loss = 2.0706727504730225
# Episode 1. Training Carried out at step = 330. Actorloss = -0.04818800464272499, Critic_loss = 1.8945828676223755
# Episode 1. Training Carried out at step = 340. Actorloss = -0.04795821011066437, Critic_loss = 1.2392008304595947
# Episode 1. Training Carried out at step = 350. Actorloss = -0.047684624791145325, Critic_loss = 0.5109907388687134
# Episode 1. Training Carried out at step = 360. Actorloss = -0.04736201465129852, Critic_loss = 0.10316193848848343
# Episode 1. Training Carried out at step = 370. Actorloss = -0.047000981867313385, Critic_loss = 0.1583285927772522
# Episode 1. Training Carried out at step = 380. Actorloss = -0.04661225900053978, Critic_loss = 0.16853518784046173
# Episode 1. Training Carried out at step = 390. Actorloss = -0.04620593413710594, Critic_loss = 0.16344527900218964
# Episode 1. Training Carried out at step = 400. Actorloss = -0.04579372704029083, Critic_loss = 0.10594899207353592
# Episode 1. Training Carried out at step = 410. Actorloss = -0.04538111016154289, Critic_loss = 0.09290013462305069
# Episode 1. Training Carried out at step = 420. Actorloss = -0.04497572034597397, Critic_loss = 0.08458247035741806
# Episode 1. Training Carried out at step = 430. Actorloss = -0.044584810733795166, Critic_loss = 0.07197441160678864
# Episode 1. Training Carried out at step = 440. Actorloss = -0.044214554131031036, Critic_loss = 0.05715997889637947
# Episode 1. Training Carried out at step = 750. Actorloss = -0.03632223978638649, Critic_loss = 0.17120051383972168
# Episode 1. Training Carried out at step = 760. Actorloss = -0.035949964076280594, Critic_loss = 0.14973387122154236
# Episode 1. Training Carried out at step = 770. Actorloss = -0.035596150904893875, Critic_loss = 0.12549203634262085
# Episode 1. Training Carried out at step = 780. Actorloss = -0.03526844084262848, Critic_loss = 0.10161353647708893
# Episode 1. Training Carried out at step = 790. Actorloss = -0.03496677801012993, Critic_loss = 0.0785149410367012
# Episode 1. Training Carried out at step = 800. Actorloss = -0.03468654304742813, Critic_loss = 0.053117815405130386
# Episode 1. Training Carried out at step = 810. Actorloss = -0.03444463759660721, Critic_loss = 0.04163351655006409
# Episode 1. Training Carried out at step = 820. Actorloss = -0.034235697239637375, Critic_loss = 0.01468874141573906
# Episode 1. Training Carried out at step = 830. Actorloss = -0.03405901417136192, Critic_loss = 0.0269640926271677
# Episode 1. Training Carried out at step = 840. Actorloss = -0.03390822187066078, Critic_loss = 0.1130516454577446
# Episode 1. Training Carried out at step = 850. Actorloss = -0.033775899559259415, Critic_loss = 0.22513175010681152
# Episode 1. Training Carried out at step = 860. Actorloss = -0.033655598759651184, Critic_loss = 0.31011199951171875
# Episode 1. Training Carried out at step = 870. Actorloss = -0.033543236553668976, Critic_loss = 0.23220917582511902
# Episode 1. Training Carried out at step = 880. Actorloss = -0.03343164548277855, Critic_loss = 0.12738007307052612
# Episode 1. Training Carried out at step = 890. Actorloss = -0.03331361711025238, Critic_loss = 0.11356943845748901
# Episode 1. Training Carried out at step = 900. Actorloss = -0.033187542110681534, Critic_loss = 0.10054735094308853
# Episode 1. Training Carried out at step = 910. Actorloss = -0.03305043280124664, Critic_loss = 0.30588847398757935
# Episode 1. Training Carried out at step = 920. Actorloss = -0.03289860486984253, Critic_loss = 1.483187198638916
# Episode 1. Training Carried out at step = 930. Actorloss = -0.03272779658436775, Critic_loss = 1.6874775886535645
# Episode 1. Training Carried out at step = 940. Actorloss = -0.032537028193473816, Critic_loss = 1.8900501728057861
# Episode 1. Training Carried out at step = 950. Actorloss = -0.03232334181666374, Critic_loss = 1.9284089803695679
# Episode 1. Training Carried out at step = 960. Actorloss = -0.032084617763757706, Critic_loss = 1.600671410560608
# Episode 1. Training Carried out at step = 970. Actorloss = -0.031818874180316925, Critic_loss = 0.8970890641212463
# Episode 1. Training Carried out at step = 980. Actorloss = -0.03152430057525635, Critic_loss = 0.21494697034358978
# Episode 1. Training Carried out at step = 990. Actorloss = -0.03119935467839241, Critic_loss = 0.1534474641084671
# Episode 1. Training Carried out at step = 1000. Actorloss = -0.0308515764772892, Critic_loss = 0.23821842670440674
# Episode 2. Training Carried out at step = 10. Actorloss = -0.030439430847764015, Critic_loss = 4.267268657684326
# Episode 2. Training Carried out at step = 20. Actorloss = -0.03008776344358921, Critic_loss = 17.214326858520508
# Episode 2. Training Carried out at step = 30. Actorloss = -0.029702845960855484, Critic_loss = 21.302522659301758
# Episode 2. Training Carried out at step = 40. Actorloss = -0.02927481383085251, Critic_loss = 2.7343358993530273
# Episode 2. Training Carried out at step = 50. Actorloss = -0.02882532775402069, Critic_loss = 0.3795457184314728
# Episode 2. Training Carried out at step = 60. Actorloss = -0.028362177312374115, Critic_loss = 0.4889514446258545
# Episode 2. Training Carried out at step = 70. Actorloss = -0.02788666822016239, Critic_loss = 0.47006940841674805
# Episode 2. Training Carried out at step = 80. Actorloss = -0.027403779327869415, Critic_loss = 0.4072837233543396
# Episode 2. Training Carried out at step = 90. Actorloss = -0.026918793097138405, Critic_loss = 0.34358787536621094
# Episode 2. Training Carried out at step = 100. Actorloss = -0.026437997817993164, Critic_loss = 0.3314197063446045
# Episode 2. Training Carried out at step = 110. Actorloss = -0.025965122506022453, Critic_loss = 0.30916649103164673
# Episode 2. Training Carried out at step = 120. Actorloss = -0.02550417184829712, Critic_loss = 0.28104886412620544
# Episode 2. Training Carried out at step = 130. Actorloss = -0.02505875565111637, Critic_loss = 0.24775998294353485
# Episode 2. Training Carried out at step = 140. Actorloss = -0.024629000574350357, Critic_loss = 0.21180182695388794
# Episode 2. Training Carried out at step = 150. Actorloss = -0.02421913854777813, Critic_loss = 0.17661358416080475
# Episode 2. Training Carried out at step = 160. Actorloss = -0.023839063942432404, Critic_loss = 0.1421840935945511
# Episode 2. Training Carried out at step = 170. Actorloss = -0.023487573489546776, Critic_loss = 0.11228752881288528
# Episode 2. Training Carried out at step = 180. Actorloss = -0.023172670975327492, Critic_loss = 0.09390714764595032
# Episode 2. Training Carried out at step = 190. Actorloss = -0.022877205163240433, Critic_loss = 0.06097203493118286
# Episode 2. Training Carried out at step = 200. Actorloss = -0.022608593106269836, Critic_loss = 0.023156702518463135
# Episode 2. Training Carried out at step = 210. Actorloss = -0.022369317710399628, Critic_loss = 0.08796804398298264
# Episode 2. Training Carried out at step = 220. Actorloss = -0.022152438759803772, Critic_loss = 0.17339472472667694
# Episode 2. Training Carried out at step = 230. Actorloss = -0.0219484344124794, Critic_loss = 0.2399182766675949
# Episode 2. Training Carried out at step = 240. Actorloss = -0.021753523498773575, Critic_loss = 0.26618528366088867
# Episode 2. Training Carried out at step = 250. Actorloss = -0.021553512662649155, Critic_loss = 0.09997093677520752
# Episode 2. Training Carried out at step = 260. Actorloss = -0.021359380334615707, Critic_loss = 0.0797189399600029
# Episode 2. Training Carried out at step = 270. Actorloss = -0.021164555102586746, Critic_loss = 0.04555850476026535
# Episode 2. Training Carried out at step = 280. Actorloss = -0.02095712162554264, Critic_loss = 0.5577378869056702
# Episode 2. Training Carried out at step = 290. Actorloss = -0.02074289135634899, Critic_loss = 1.0271739959716797
# Episode 2. Training Carried out at step = 300. Actorloss = -0.020517461001873016, Critic_loss = 1.4056875705718994
# Episode 2. Training Carried out at step = 310. Actorloss = -0.020277515053749084, Critic_loss = 1.5824925899505615
# Episode 2. Training Carried out at step = 320. Actorloss = -0.020017312839627266, Critic_loss = 1.571724772453308
# Episode 2. Training Carried out at step = 330. Actorloss = -0.019738059490919113, Critic_loss = 1.4442778825759888
# Episode 2. Training Carried out at step = 340. Actorloss = -0.019436825066804886, Critic_loss = 0.9699320197105408
# Episode 2. Training Carried out at step = 350. Actorloss = -0.019111961126327515, Critic_loss = 0.39394500851631165
# Episode 2. Training Carried out at step = 360. Actorloss = -0.018762236461043358, Critic_loss = 0.07736397534608841
# Episode 2. Training Carried out at step = 370. Actorloss = -0.018387969583272934, Critic_loss = 0.27948734164237976
# Episode 2. Training Carried out at step = 380. Actorloss = -0.017993489280343056, Critic_loss = 0.3009185791015625
# Episode 2. Training Carried out at step = 390. Actorloss = -0.017587192356586456, Critic_loss = 0.2982020974159241
# Episode 2. Training Carried out at step = 400. Actorloss = -0.017169909551739693, Critic_loss = 0.22382980585098267
# Episode 2. Training Carried out at step = 410. Actorloss = -0.016754621639847755, Critic_loss = 0.20874053239822388
# Episode 2. Training Carried out at step = 420. Actorloss = -0.01634632609784603, Critic_loss = 0.203809916973114
# Episode 2. Training Carried out at step = 430. Actorloss = -0.01594211347401142, Critic_loss = 0.19219204783439636
# Episode 2. Training Carried out at step = 440. Actorloss = -0.01554886344820261, Critic_loss = 0.17572087049484253
# Episode 2. Training Carried out at step = 450. Actorloss = -0.015173635445535183, Critic_loss = 0.1560835838317871
# Episode 2. Training Carried out at step = 460. Actorloss = -0.014813479036092758, Critic_loss = 0.13462451100349426
# Episode 2. Training Carried out at step = 470. Actorloss = -0.014467630535364151, Critic_loss = 0.11246126890182495
# Episode 2. Training Carried out at step = 480. Actorloss = -0.014149303548038006, Critic_loss = 0.0915449783205986
# Episode 2. Training Carried out at step = 490. Actorloss = -0.013878165744245052, Critic_loss = 0.07940541952848434
# Episode 2. Training Carried out at step = 500. Actorloss = -0.013617155142128468, Critic_loss = 0.05600745975971222
# Episode 2. Training Carried out at step = 510. Actorloss = -0.013375673443078995, Critic_loss = 0.011756297200918198
# Episode 2. Training Carried out at step = 520. Actorloss = -0.013144366443157196, Critic_loss = 0.04986371099948883
# Episode 2. Training Carried out at step = 530. Actorloss = -0.012946958653628826, Critic_loss = 0.13185028731822968
# Episode 2. Training Carried out at step = 540. Actorloss = -0.012764687649905682, Critic_loss = 0.22087591886520386
# Episode 2. Training Carried out at step = 550. Actorloss = -0.01258936058729887, Critic_loss = 0.2705900967121124
# Episode 2. Training Carried out at step = 560. Actorloss = -0.01239602081477642, Critic_loss = 0.1713353842496872
# Episode 2. Training Carried out at step = 570. Actorloss = -0.012208045460283756, Critic_loss = 0.09327979385852814
# Episode 2. Training Carried out at step = 580. Actorloss = -0.012031364254653454, Critic_loss = 0.08108088374137878
# Episode 2. Training Carried out at step = 590. Actorloss = -0.011854875832796097, Critic_loss = 0.14183054864406586
# Episode 2. Training Carried out at step = 600. Actorloss = -0.01165735349059105, Critic_loss = 0.8561082482337952
# Episode 2. Training Carried out at step = 610. Actorloss = -0.0114470599219203, Critic_loss = 1.2600184679031372
# Episode 2. Training Carried out at step = 620. Actorloss = -0.011228117160499096, Critic_loss = 1.7023144960403442
# Episode 2. Training Carried out at step = 630. Actorloss = -0.010998127982020378, Critic_loss = 1.7020593881607056
# Episode 2. Training Carried out at step = 640. Actorloss = -0.010741900652647018, Critic_loss = 1.6688804626464844
# Episode 2. Training Carried out at step = 650. Actorloss = -0.010464752092957497, Critic_loss = 1.313777208328247
# Episode 2. Training Carried out at step = 660. Actorloss = -0.01016779150813818, Critic_loss = 0.6513961553573608
# Episode 2. Training Carried out at step = 670. Actorloss = -0.009848532266914845, Critic_loss = 0.14764364063739777
# Episode 2. Training Carried out at step = 680. Actorloss = -0.009504501707851887, Critic_loss = 0.18236470222473145
# Episode 2. Training Carried out at step = 690. Actorloss = -0.009137837216258049, Critic_loss = 0.24334612488746643
# Episode 2. Training Carried out at step = 700. Actorloss = -0.008755771443247795, Critic_loss = 0.24571645259857178
# Episode 2. Training Carried out at step = 710. Actorloss = -0.008361738175153732, Critic_loss = 0.21228455007076263
# Episode 2. Training Carried out at step = 720. Actorloss = -0.00796480942517519, Critic_loss = 0.1576177477836609
# Episode 2. Training Carried out at step = 730. Actorloss = -0.007570380344986916, Critic_loss = 0.1555698961019516
# Episode 2. Training Carried out at step = 740. Actorloss = -0.0071799252182245255, Critic_loss = 0.14863604307174683
# Episode 2. Training Carried out at step = 750. Actorloss = -0.006803990341722965, Critic_loss = 0.1371893286705017
# Episode 2. Training Carried out at step = 760. Actorloss = -0.006435728166252375, Critic_loss = 0.12246035039424896
# Episode 2. Training Carried out at step = 770. Actorloss = -0.006092225667089224, Critic_loss = 0.10626401007175446
# Episode 2. Training Carried out at step = 780. Actorloss = -0.0057536582462489605, Critic_loss = 0.08959943056106567
# Episode 2. Training Carried out at step = 790. Actorloss = -0.005437877494841814, Critic_loss = 0.07290574163198471
# Episode 2. Training Carried out at step = 800. Actorloss = -0.005179019644856453, Critic_loss = 0.05688056722283363
# Episode 2. Training Carried out at step = 810. Actorloss = -0.004927553702145815, Critic_loss = 0.04658907651901245
# Episode 2. Training Carried out at step = 820. Actorloss = -0.004686913453042507, Critic_loss = 0.021527348086237907
# Episode 2. Training Carried out at step = 830. Actorloss = -0.004452966619282961, Critic_loss = 0.021434959024190903
# Episode 2. Training Carried out at step = 840. Actorloss = -0.004233434330672026, Critic_loss = 0.10024528205394745
# Episode 2. Training Carried out at step = 850. Actorloss = -0.00404506828635931, Critic_loss = 0.20708408951759338
# Episode 2. Training Carried out at step = 860. Actorloss = -0.003869426902383566, Critic_loss = 0.28369131684303284
# Episode 2. Training Carried out at step = 870. Actorloss = -0.003674435196444392, Critic_loss = 0.2486657202243805
# Episode 2. Training Carried out at step = 880. Actorloss = -0.0034579329658299685, Critic_loss = 0.11497178673744202
# Episode 2. Training Carried out at step = 890. Actorloss = -0.0032788689713925123, Critic_loss = 0.10156357288360596
# Episode 2. Training Carried out at step = 900. Actorloss = -0.0030993525870144367, Critic_loss = 0.08109847456216812
# Episode 2. Training Carried out at step = 910. Actorloss = -0.0029148058965802193, Critic_loss = 0.39490756392478943
# Episode 2. Training Carried out at step = 920. Actorloss = -0.0027014834340661764, Critic_loss = 1.2630192041397095
# Episode 2. Training Carried out at step = 930. Actorloss = -0.0024908140767365694, Critic_loss = 1.6132419109344482
# Episode 2. Training Carried out at step = 940. Actorloss = -0.002272629179060459, Critic_loss = 1.8364510536193848
# Episode 2. Training Carried out at step = 950. Actorloss = -0.002021652879193425, Critic_loss = 1.882411241531372
# Episode 2. Training Carried out at step = 960. Actorloss = -0.001757191144861281, Critic_loss = 1.6133228540420532
# Episode 2. Training Carried out at step = 970. Actorloss = -0.0014737220481038094, Critic_loss = 0.9799559116363525
# Episode 2. Training Carried out at step = 980. Actorloss = -0.001171040814369917, Critic_loss = 0.31807222962379456
# Episode 2. Training Carried out at step = 990. Actorloss = -0.0008602096349932253, Critic_loss = 0.09747928380966187
# Episode 2. Training Carried out at step = 1000. Actorloss = -0.0005090349586680532, Critic_loss = 0.20386870205402374
# Episode 3. Training Carried out at step = 10. Actorloss = -0.0010142545215785503, Critic_loss = 4.1873087882995605
# Episode 3. Training Carried out at step = 20. Actorloss = -0.0006924434565007687, Critic_loss = 17.133798599243164
# Episode 3. Training Carried out at step = 30. Actorloss = -0.00030780036468058825, Critic_loss = 21.205991744995117
# Episode 3. Training Carried out at step = 40. Actorloss = 8.888739830581471e-05, Critic_loss = 2.69667387008667
# Episode 3. Training Carried out at step = 50. Actorloss = 0.000514100247528404, Critic_loss = 0.34407490491867065
# Episode 3. Training Carried out at step = 60. Actorloss = 0.0009668027050793171, Critic_loss = 0.42905929684638977
# Episode 3. Training Carried out at step = 70. Actorloss = 0.001418133033439517, Critic_loss = 0.4082326591014862
# Episode 3. Training Carried out at step = 80. Actorloss = 0.0018862002762034535, Critic_loss = 0.34793055057525635
# Episode 3. Training Carried out at step = 90. Actorloss = 0.0023611432407051325, Critic_loss = 0.2905822694301605
# Episode 3. Training Carried out at step = 100. Actorloss = 0.0028227088041603565, Critic_loss = 0.2828774154186249
# Episode 3. Training Carried out at step = 110. Actorloss = 0.003278633812442422, Critic_loss = 0.2682933211326599
# Episode 3. Training Carried out at step = 120. Actorloss = 0.0037254421040415764, Critic_loss = 0.24830852448940277
# Episode 3. Training Carried out at step = 130. Actorloss = 0.004160079173743725, Critic_loss = 0.22470249235630035
# Episode 3. Training Carried out at step = 140. Actorloss = 0.0046021356247365475, Critic_loss = 0.19869454205036163
# Episode 3. Training Carried out at step = 150. Actorloss = 0.005024394486099482, Critic_loss = 0.17158901691436768
# Episode 3. Training Carried out at step = 160. Actorloss = 0.005392295774072409, Critic_loss = 0.14453072845935822
# Episode 3. Training Carried out at step = 170. Actorloss = 0.0057194968685507774, Critic_loss = 0.11601749807596207
# Episode 3. Training Carried out at step = 180. Actorloss = 0.005967098753899336, Critic_loss = 0.10896019637584686
# Episode 3. Training Carried out at step = 190. Actorloss = 0.006267447490245104, Critic_loss = 0.0749019905924797
# Episode 3. Training Carried out at step = 200. Actorloss = 0.006585980299860239, Critic_loss = 0.021354615688323975
# Episode 3. Training Carried out at step = 210. Actorloss = 0.006836164277046919, Critic_loss = 0.06447823345661163
# Episode 3. Training Carried out at step = 220. Actorloss = 0.007053741253912449, Critic_loss = 0.1419515758752823
# Episode 3. Training Carried out at step = 230. Actorloss = 0.007275135722011328, Critic_loss = 0.19774870574474335
# Episode 3. Training Carried out at step = 540. Actorloss = 0.016621502116322517, Critic_loss = 0.18294280767440796
# Episode 3. Training Carried out at step = 550. Actorloss = 0.016832344233989716, Critic_loss = 0.22925767302513123
# Episode 3. Training Carried out at step = 560. Actorloss = 0.0170968696475029, Critic_loss = 0.14102298021316528
# Episode 3. Training Carried out at step = 570. Actorloss = 0.01734812743961811, Critic_loss = 0.07122422754764557
# Episode 3. Training Carried out at step = 580. Actorloss = 0.017552809789776802, Critic_loss = 0.06066003814339638
# Episode 3. Training Carried out at step = 590. Actorloss = 0.01772075518965721, Critic_loss = 0.12368745356798172
# Episode 3. Training Carried out at step = 600. Actorloss = 0.017950423061847687, Critic_loss = 0.7698186635971069
# Episode 3. Training Carried out at step = 610. Actorloss = 0.018182069063186646, Critic_loss = 1.1666302680969238
# Episode 3. Training Carried out at step = 620. Actorloss = 0.01840951479971409, Critic_loss = 1.6041654348373413
# Episode 3. Training Carried out at step = 630. Actorloss = 0.018653245642781258, Critic_loss = 1.6076953411102295
# Episode 3. Training Carried out at step = 640. Actorloss = 0.018915144726634026, Critic_loss = 1.5912491083145142
# Episode 3. Training Carried out at step = 650. Actorloss = 0.019196921959519386, Critic_loss = 1.2722628116607666
# Episode 3. Training Carried out at step = 660. Actorloss = 0.019487179815769196, Critic_loss = 0.6440674066543579
# Episode 3. Training Carried out at step = 670. Actorloss = 0.01979987882077694, Critic_loss = 0.15503151714801788
# Episode 3. Training Carried out at step = 680. Actorloss = 0.020117754116654396, Critic_loss = 0.17862588167190552
# Episode 3. Training Carried out at step = 690. Actorloss = 0.020471468567848206, Critic_loss = 0.2450888454914093
# Episode 3. Training Carried out at step = 700. Actorloss = 0.020838089287281036, Critic_loss = 0.2443361133337021
# Episode 3. Training Carried out at step = 710. Actorloss = 0.02122662402689457, Critic_loss = 0.20882278680801392
# Episode 3. Training Carried out at step = 720. Actorloss = 0.02162642404437065, Critic_loss = 0.15488407015800476
# Episode 3. Training Carried out at step = 730. Actorloss = 0.021994493901729584, Critic_loss = 0.15339575707912445
# Episode 3. Training Carried out at step = 740. Actorloss = 0.02237527072429657, Critic_loss = 0.14715270698070526
# Episode 3. Training Carried out at step = 750. Actorloss = 0.022740496322512627, Critic_loss = 0.1378927379846573
# Episode 3. Training Carried out at step = 760. Actorloss = 0.02311065047979355, Critic_loss = 0.1257379800081253
# Episode 3. Training Carried out at step = 770. Actorloss = 0.023452460765838623, Critic_loss = 0.11171377450227737
# Episode 3. Training Carried out at step = 780. Actorloss = 0.023783981800079346, Critic_loss = 0.09684865176677704
# Episode 3. Training Carried out at step = 790. Actorloss = 0.024089142680168152, Critic_loss = 0.08158466219902039
# Episode 3. Training Carried out at step = 800. Actorloss = 0.02430572919547558, Critic_loss = 0.0667518749833107
# Episode 3. Training Carried out at step = 810. Actorloss = 0.02450384758412838, Critic_loss = 0.053978729993104935
# Episode 3. Training Carried out at step = 820. Actorloss = 0.024780642241239548, Critic_loss = 0.024013886228203773
# Episode 3. Training Carried out at step = 830. Actorloss = 0.025045787915587425, Critic_loss = 0.016698084771633148
# Episode 3. Training Carried out at step = 840. Actorloss = 0.02532694861292839, Critic_loss = 0.08689159154891968
# Episode 3. Training Carried out at step = 850. Actorloss = 0.025502298027276993, Critic_loss = 0.17917178571224213
# Episode 3. Training Carried out at step = 860. Actorloss = 0.02571045607328415, Critic_loss = 0.2515963017940521
# Episode 3. Training Carried out at step = 870. Actorloss = 0.025944892317056656, Critic_loss = 0.21952298283576965
# Episode 3. Training Carried out at step = 880. Actorloss = 0.026247071102261543, Critic_loss = 0.0965963751077652
# Episode 3. Training Carried out at step = 890. Actorloss = 0.026458119973540306, Critic_loss = 0.08427077531814575
# Episode 3. Training Carried out at step = 900. Actorloss = 0.026646655052900314, Critic_loss = 0.06643888354301453
# Episode 3. Training Carried out at step = 910. Actorloss = 0.02680850215256214, Critic_loss = 0.36639881134033203
# Episode 3. Training Carried out at step = 920. Actorloss = 0.027047086507081985, Critic_loss = 1.1915297508239746
# Episode 3. Training Carried out at step = 930. Actorloss = 0.02728012576699257, Critic_loss = 1.5380210876464844
# Episode 3. Training Carried out at step = 940. Actorloss = 0.02750755473971367, Critic_loss = 1.7639333009719849
# Episode 3. Training Carried out at step = 950. Actorloss = 0.02776438742876053, Critic_loss = 1.8125343322753906
# Episode 3. Training Carried out at step = 960. Actorloss = 0.028025364503264427, Critic_loss = 1.5811173915863037
# Episode 3. Training Carried out at step = 970. Actorloss = 0.028302032500505447, Critic_loss = 0.9776952266693115
# Episode 3. Training Carried out at step = 980. Actorloss = 0.028599971905350685, Critic_loss = 0.3249157667160034
# Episode 3. Training Carried out at step = 990. Actorloss = 0.028888799250125885, Critic_loss = 0.10019589215517044
# Episode 3. Training Carried out at step = 1000. Actorloss = 0.029216093942523003, Critic_loss = 0.20434841513633728
# Episode 4. Training Carried out at step = 10. Actorloss = 0.0272003673017025, Critic_loss = 4.107243537902832
# Episode 4. Training Carried out at step = 20. Actorloss = 0.02758929319679737, Critic_loss = 16.859697341918945
# Episode 4. Training Carried out at step = 30. Actorloss = 0.027860239148139954, Critic_loss = 21.934551239013672
# Episode 4. Training Carried out at step = 40. Actorloss = 0.028325892984867096, Critic_loss = 3.717557430267334
# Episode 4. Training Carried out at step = 50. Actorloss = 0.02875479683279991, Critic_loss = 0.3745053708553314
# Episode 4. Training Carried out at step = 60. Actorloss = 0.029188139364123344, Critic_loss = 0.42454251646995544
# Episode 4. Training Carried out at step = 70. Actorloss = 0.02963494509458542, Critic_loss = 0.4176729619503021
# Episode 4. Training Carried out at step = 80. Actorloss = 0.030093004927039146, Critic_loss = 0.35469016432762146
# Episode 4. Training Carried out at step = 90. Actorloss = 0.03058708645403385, Critic_loss = 0.2922283411026001
# Episode 4. Training Carried out at step = 100. Actorloss = 0.031044401228427887, Critic_loss = 0.2860412299633026
# Episode 4. Training Carried out at step = 110. Actorloss = 0.031497400254011154, Critic_loss = 0.2743682563304901
# Episode 4. Training Carried out at step = 120. Actorloss = 0.03194313868880272, Critic_loss = 0.2576066553592682
# Episode 4. Training Carried out at step = 130. Actorloss = 0.03237910568714142, Critic_loss = 0.23739798367023468
# Episode 23. Training Carried out at step = 390. Actorloss = 0.059143904596567154, Critic_loss = 0.0026792900171130896
# Episode 23. Training Carried out at step = 400. Actorloss = 0.05939250811934471, Critic_loss = 0.002911000046879053
# Episode 23. Training Carried out at step = 410. Actorloss = 0.05964392423629761, Critic_loss = 0.0031206996645778418
# Episode 23. Training Carried out at step = 420. Actorloss = 0.05988562852144241, Critic_loss = 0.003245628671720624
# Episode 23. Training Carried out at step = 430. Actorloss = 0.06012708693742752, Critic_loss = 0.003261236008256674
# Episode 23. Training Carried out at step = 440. Actorloss = 0.06036584451794624, Critic_loss = 0.0031744621228426695
# Episode 23. Training Carried out at step = 450. Actorloss = 0.06059299036860466, Critic_loss = 0.003019754309207201
# Episode 23. Training Carried out at step = 460. Actorloss = 0.060814641416072845, Critic_loss = 0.002843234222382307
# Episode 23. Training Carried out at step = 470. Actorloss = 0.0610298216342926, Critic_loss = 0.0026782206259667873
# Episode 23. Training Carried out at step = 480. Actorloss = 0.06123720109462738, Critic_loss = 0.0025548585690557957
# Episode 23. Training Carried out at step = 490. Actorloss = 0.06144052743911743, Critic_loss = 0.002482392592355609
# Episode 23. Training Carried out at step = 500. Actorloss = 0.061640020459890366, Critic_loss = 0.0024645235389471054
# Episode 23. Training Carried out at step = 510. Actorloss = 0.06183489412069321, Critic_loss = 0.0024890918284654617
# Episode 23. Training Carried out at step = 520. Actorloss = 0.062026407569646835, Critic_loss = 0.002537031192332506
# Episode 23. Training Carried out at step = 530. Actorloss = 0.06221587955951691, Critic_loss = 0.0025940006598830223
# Episode 23. Training Carried out at step = 540. Actorloss = 0.06240411102771759, Critic_loss = 0.0026404969394207
# Episode 23. Training Carried out at step = 550. Actorloss = 0.0625908151268959, Critic_loss = 0.002665645210072398
# Episode 23. Training Carried out at step = 560. Actorloss = 0.06277770549058914, Critic_loss = 0.002661103615537286
# Episode 23. Training Carried out at step = 570. Actorloss = 0.0629652664065361, Critic_loss = 0.0026355781592428684
# Episode 23. Training Carried out at step = 580. Actorloss = 0.06315334141254425, Critic_loss = 0.0025921151973307133
# Episode 23. Training Carried out at step = 590. Actorloss = 0.06334298104047775, Critic_loss = 0.0025465732906013727
# Episode 23. Training Carried out at step = 600. Actorloss = 0.06353411823511124, Critic_loss = 0.00249806372448802
# Episode 23. Training Carried out at step = 610. Actorloss = 0.06372259557247162, Critic_loss = 0.002460629213601351
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-53fe032dce0a> in <module>
#      46             print("episode_count set to ", episode_count)
#      47
# ---> 48         worker.work(sess, coord, saver, global_summary) # Start Training / Testing operation
#      49
#      50 # if not TRAINING:
#
# <ipython-input-19-132ba1192f80> in work(self, sess, coord, saver, summary)
#      91                     # Obtain the action as output by our actor network based on current state
#      92                     feed_dict = {self.global_network.observation_input_placeholder: s}
# ---> 93                     a = sess.run(self.global_network.actor_net_output, feed_dict = feed_dict)
#      94
#      95                     if TRAINING:
#
# ~/anaconda3/envs/me5418-p1/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     885     try:
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#     889         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/me5418-p1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1108     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#    1112       results = []
#
# ~/anaconda3/envs/me5418-p1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1284     if handle is None:
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#    1288       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/me5418-p1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1290   def _do_call(self, fn, *args):
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#    1294       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/me5418-p1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1275       self._extend_graph()
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#    1279     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/me5418-p1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1365     return tf_session.TF_SessionRun_wrapper(
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#    1369   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Disconnect Cell
# If we manually end the training operation by stopping the cell above (Keyboard Interuption), pybullet window would still be running.
#
# Run the cell below to properly terminate the pybullet window

# %%
gameEnv.disconnect()
